# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Load data

# %%
source = pd.read_csv('../Deliverable1Dataset.csv')
data = source.copy()

# %% [markdown]
# ### Item
#
# - Find all the observations that missing values

# %%
total_missing_items = data['Item'].isnull().sum()
print(f'Total number of missing rows for Item: {total_missing_items}')

total_missing_items_observations = data[data['Item'].isnull()]
total_missing_items_observations.head(50)
# Out:
# Total number of missing rows for Item: 1213
#     Transaction ID Customer ID                            Category Item  \
# 6      TXN_1005543     CUST_19                                Food  NaN
# 13     TXN_1007496     CUST_01                            Butchers  NaN
# 51     TXN_1032287     CUST_16                                Food  NaN
# 64     TXN_1041483     CUST_19       Electric household essentials  NaN
# 65     TXN_1041890     CUST_03                           Furniture  NaN
# 71     TXN_1044590     CUST_12       Electric household essentials  NaN
# 73     TXN_1046262     CUST_14                       Milk Products  NaN
# 74     TXN_1046367     CUST_21  Computers and electric accessories  NaN
# 79     TXN_1051223     CUST_08                          Patisserie  NaN
# 90     TXN_1058643     CUST_23                                Food  NaN
# 104    TXN_1069238     CUST_23                                Food  NaN
# 108    TXN_1071762     CUST_19                           Beverages  NaN
# 138    TXN_1095879     CUST_15                           Beverages  NaN
# 140    TXN_1096977     CUST_07                                Food  NaN
# 180    TXN_1130015     CUST_23                       Milk Products  NaN
# 195    TXN_1136695     CUST_18                                Food  NaN
# 197    TXN_1137542     CUST_21       Electric household essentials  NaN
# 216    TXN_1153995     CUST_03       Electric household essentials  NaN
# 217    TXN_1154680     CUST_25                           Furniture  NaN
# 225    TXN_1158381     CUST_24                            Butchers  NaN
# 232    TXN_1164094     CUST_09                          Patisserie  NaN
# 249    TXN_1175914     CUST_13                            Butchers  NaN
# 262    TXN_1187836     CUST_01  Computers and electric accessories  NaN
# 288    TXN_1199916     CUST_21                           Furniture  NaN
# 289    TXN_1201215     CUST_13  Computers and electric accessories  NaN
# 295    TXN_1202968     CUST_11       Electric household essentials  NaN
# 305    TXN_1207984     CUST_17                                Food  NaN
# 306    TXN_1208593     CUST_21                          Patisserie  NaN
# 307    TXN_1208768     CUST_24                           Beverages  NaN
# 313    TXN_1211345     CUST_19                           Furniture  NaN
# 316    TXN_1212399     CUST_05                           Beverages  NaN
# 325    TXN_1220541     CUST_21                                Food  NaN
# 332    TXN_1223128     CUST_13                            Butchers  NaN
# 337    TXN_1226245     CUST_18                                Food  NaN
# 339    TXN_1228408     CUST_01                          Patisserie  NaN
# 348    TXN_1236974     CUST_01                           Beverages  NaN
# 371    TXN_1255913     CUST_21                          Patisserie  NaN
# 393    TXN_1276885     CUST_23                          Patisserie  NaN
# 401    TXN_1284380     CUST_06       Electric household essentials  NaN
# 405    TXN_1285469     CUST_20       Electric household essentials  NaN
# 429    TXN_1306295     CUST_15  Computers and electric accessories  NaN
# 431    TXN_1310254     CUST_20                       Milk Products  NaN
# 452    TXN_1322913     CUST_18                                Food  NaN
# 466    TXN_1337454     CUST_09                                Food  NaN
# 482    TXN_1352194     CUST_17       Electric household essentials  NaN
# 514    TXN_1372952     CUST_21                           Furniture  NaN
# 524    TXN_1376742     CUST_24                          Patisserie  NaN
# 530    TXN_1382421     CUST_14                           Beverages  NaN
# 559    TXN_1396754     CUST_18                       Milk Products  NaN
# 568    TXN_1402550     CUST_15                          Patisserie  NaN
#
#      Price Per Unit  Quantity  Total Spent  Payment Method  Location  \
# 6              30.5       NaN          NaN            Cash  In-store
# 13              NaN      10.0        155.0     Credit Card    Online
# 51              NaN       2.0         43.0            Cash    Online
# 64             15.5       NaN          NaN            Cash  In-store
# 65             27.5       NaN          NaN  Digital Wallet    Online
# 71              NaN       4.0         56.0            Cash    Online
# 73              NaN       5.0         70.0            Cash  In-store
# 74              NaN      10.0        185.0            Cash  In-store
# 79              NaN       9.0         45.0     Credit Card    Online
# 90              NaN       2.0         19.0  Digital Wallet  In-store
# 104             5.0       NaN          NaN  Digital Wallet  In-store
# 108             NaN       3.0         28.5            Cash  In-store
# 138             NaN      10.0         65.0  Digital Wallet  In-store
# 140             NaN       9.0        207.0            Cash  In-store
# 180             9.5       NaN          NaN            Cash  In-store
# 195             NaN       8.0         76.0  Digital Wallet  In-store
# 197             NaN       1.0         11.0     Credit Card  In-store
# 216            23.0       NaN          NaN     Credit Card  In-store
# 217            35.0       NaN          NaN     Credit Card    Online
# 225            36.5       NaN          NaN     Credit Card    Online
# 232             NaN       3.0         33.0  Digital Wallet  In-store
# 249            23.0       NaN          NaN            Cash  In-store
# 262            38.0       NaN          NaN  Digital Wallet  In-store
# 288             6.5       NaN          NaN  Digital Wallet  In-store
# 289             NaN       6.0         93.0            Cash    Online
# 295             NaN       8.0        112.0  Digital Wallet    Online
# 305             NaN       6.0        174.0     Credit Card  In-store
# 306            20.0       NaN          NaN     Credit Card  In-store
# 307             NaN       2.0         28.0            Cash    Online
# 313             NaN       7.0         66.5  Digital Wallet    Online
# 316             NaN       8.0        112.0  Digital Wallet    Online
# 325            35.0       NaN          NaN  Digital Wallet  In-store
# 332            26.0       NaN          NaN  Digital Wallet  In-store
# 337            21.5       NaN          NaN     Credit Card  In-store
# 339            41.0       NaN          NaN            Cash    Online
# 348             NaN       8.0         76.0            Cash    Online
# 371             NaN       1.0         38.0  Digital Wallet    Online
# 393             5.0       NaN          NaN            Cash  In-store
# 401             NaN       4.0         62.0            Cash  In-store
# 405             NaN       7.0        108.5  Digital Wallet    Online
# 429             NaN       5.0         32.5  Digital Wallet    Online
# 431             NaN       8.0        232.0  Digital Wallet    Online
# 452             NaN       4.0         80.0  Digital Wallet    Online
# 466            41.0       NaN          NaN  Digital Wallet  In-store
# 482             NaN       4.0         86.0     Credit Card    Online
# 514            33.5       NaN          NaN  Digital Wallet  In-store
# 524            17.0       NaN          NaN     Credit Card    Online
# 530            33.5       NaN          NaN     Credit Card  In-store
# 559             NaN       4.0         62.0  Digital Wallet  In-store
# 568            29.0       NaN          NaN     Credit Card    Online
#
#     Transaction Date Discount Applied
# 6         2022-12-03             True
# 13        2024-02-05             True
# 51        2022-07-27              NaN
# 64        2024-03-19              NaN
# 65        2022-07-02            False
# 71        2024-05-07            False
# 73        2022-11-19            False
# 74        2022-06-21              NaN
# 79        2023-10-25              NaN
# 90        2024-10-01            False
# 104       2022-08-13            False
# 108       2024-10-31              NaN
# 138       2023-02-04             True
# 140       2024-12-07            False
# 180       2024-03-27            False
# 195       2024-03-24             True
# 197       2023-06-29              NaN
# 216       2022-02-12            False
# 217       2022-12-18            False
# 225       2022-12-26             True
# 232       2024-07-29              NaN
# 249       2023-05-19            False
# 262       2022-12-20            False
# 288       2022-06-25              NaN
# 289       2022-10-03             True
# 295       2022-09-03             True
# 305       2022-05-10              NaN
# 306       2022-11-19              NaN
# 307       2023-02-28              NaN
# 313       2024-12-02              NaN
# 316       2024-01-17             True
# 325       2023-12-03            False
# 332       2023-10-24            False
# 337       2023-05-31              NaN
# 339       2023-12-19              NaN
# 348       2023-04-21            False
# 371       2024-01-18            False
# 393       2024-12-30              NaN
# 401       2023-07-14             True
# 405       2022-06-17            False
# 429       2022-09-13             True
# 431       2022-03-16             True
# 452       2022-09-20             True
# 466       2022-11-05             True
# 482       2023-02-26              NaN
# 514       2024-04-02             True
# 524       2024-10-20             True
# 530       2024-07-12              NaN
# 559       2022-05-07             True
# 568       2024-05-01            False

# %% [markdown]
# ### Item missingness analysis
#
# - Evaluate where `Item` values are absent to understand dependencies.

# %%
item_missing = data['Item'].isna()

print(f'Missing Item count: {item_missing.sum()} of {len(data)} rows ({item_missing.mean():.2%})')
print('Share of Item missing by Category (top 5):')
print(data.assign(item_missing=item_missing).groupby('Category')['item_missing'].mean().sort_values(ascending=False).head())
print('Share of Item missing by Payment Method:')
print(data.assign(item_missing=item_missing).groupby('Payment Method')['item_missing'].mean().sort_values(ascending=False))
# Out:
# Missing Item count: 1213 of 12575 rows (9.65%)
# Share of Item missing by Category (top 5):
# Category
# Patisserie                            0.104058
# Computers and electric accessories    0.103338
# Food                                  0.102015
# Milk Products                         0.100379
# Electric household essentials         0.096794
# Name: item_missing, dtype: float64
# Share of Item missing by Payment Method:
# Payment Method
# Digital Wallet    0.103282
# Credit Card       0.095123
# Cash              0.091183
# Name: item_missing, dtype: float64

# %% [markdown]
# ### Identify the missingness
#
# `Item` missed along with `Price Per Unit` and `Category`, indicating a Missing At Random (MAR) mechanism.
#
# ### Handle MAR issue
# - Need to fill in all the missing values, first to check to see their relationship for those observations that has values
# - Will need to fill in the missing values based on the existing observations but those existed observation have to be unique in order to create a mapping between

# %%
lookup_conflicts = (
    data.dropna(subset=['Category', 'Price Per Unit', 'Item'])
    .groupby(['Category', 'Price Per Unit'])['Item']
    .nunique()
)
conflicts = lookup_conflicts[lookup_conflicts > 1]
print(f'Category+Price combinations without unique Item mapping: {len(conflicts)}')
# Out:
# Category+Price combinations without unique Item mapping: 0

# %% [markdown]
# ### Fill in missing values for Item
#
# Derive deterministic `Item` values from `Category` and `Price Per Unit`. When unit price is missing but `Quantity` and `Total Spent` are present, reconstruct the price before mapping.

# %%
# Flag rows where Item and Price per Unit are missing but quantity and total are available
needs_price = (
    data['Item'].isna() &
    data['Price Per Unit'].isna() &
    data['Quantity'].notna() &
    data['Total Spent'].notna()
)
# Recompute unit prices for those rows before attempting Item lookup
data.loc[needs_price, 'Price Per Unit'] = (
    data.loc[needs_price, 'Total Spent'] / data.loc[needs_price, 'Quantity']
).round(1)
print(data)
# Build Category+Price lookup table mapping back to the expected Item code
# only need to set index for all the rows that have the values of the category and price per unit (remove all the rows that have invalid values for outliers)
# do the same with duplicated rows then create a mapping table between [category and price per unit] and item e.g ('Furniture', 6.5) -> Item_18_FOOD
item_lookup = (
    data.dropna(subset=['Category', 'Price Per Unit', 'Item'])
    .drop_duplicates(subset=['Category', 'Price Per Unit'])
    .set_index(['Category', 'Price Per Unit'])['Item']
)

print(item_lookup)
# Apply lookup to rows still missing Item values
# create a mapping table between category and price per unit e.g, ('Food', 11.0), ('Furniture', 6.5)
keys = list(zip(data['Category'], data['Price Per Unit']))
data['Item'] = data['Item'].fillna(pd.Series(keys, index=data.index).map(item_lookup))
# Out:
#       Transaction ID Customer ID                            Category  \
# 0        TXN_1002182     CUST_01                                Food
# 1        TXN_1003865     CUST_15                           Furniture
# 2        TXN_1003940     CUST_06                           Furniture
# 3        TXN_1004091     CUST_04                                Food
# 4        TXN_1004124     CUST_08  Computers and electric accessories
# ...              ...         ...                                 ...
# 12570    TXN_9996909     CUST_23                           Furniture
# 12571    TXN_9997234     CUST_02                            Butchers
# 12572    TXN_9998575     CUST_13                                Food
# 12573    TXN_9999124     CUST_02                            Butchers
# 12574    TXN_9999729     CUST_15                            Butchers
#
#                Item  Price Per Unit  Quantity  Total Spent  Payment Method  \
# 0       Item_5_FOOD            11.0       5.0         55.0  Digital Wallet
# 1        Item_2_FUR             6.5       5.0         32.5            Cash
# 2        Item_5_FUR            11.0       9.0         99.0  Digital Wallet
# 3      Item_25_FOOD            41.0       3.0        123.0            Cash
# 4        Item_7_CEA            14.0       5.0         70.0     Credit Card
# ...             ...             ...       ...          ...             ...
# 12570    Item_8_FUR            15.5      10.0        155.0  Digital Wallet
# 12571   Item_25_BUT            41.0       8.0        328.0            Cash
# 12572   Item_6_FOOD            12.5       9.0        112.5     Credit Card
# 12573           NaN            36.5       NaN          NaN  Digital Wallet
# 12574   Item_23_BUT            38.0       5.0        190.0            Cash
#
#        Location Transaction Date Discount Applied
# 0      In-store       2024-10-08             True
# 1        Online       2022-03-12            False
# 2        Online       2022-04-22            False
# 3      In-store       2023-11-09            False
# 4      In-store       2022-03-02              NaN
# ...         ...              ...              ...
# 12570    Online       2024-09-06              NaN
# 12571  In-store       2024-09-26              NaN
# 12572  In-store       2024-01-02             True
# 12573  In-store       2024-02-21            False
# 12574  In-store       2022-10-28              NaN
#
# [12575 rows x 11 columns]
# Category                            Price Per Unit
# Food                                11.0               Item_5_FOOD
# Furniture                           6.5                 Item_2_FUR
#                                     11.0                Item_5_FUR
# Food                                41.0              Item_25_FOOD
# Computers and electric accessories  14.0                Item_7_CEA
#                                                           ...
# Milk Products                       18.5              Item_10_MILK
# Electric household essentials       24.5               Item_14_EHE
# Furniture                           23.0               Item_13_FUR
# Milk Products                       24.5              Item_14_MILK
# Beverages                           23.0               Item_13_BEV
# Name: Item, Length: 200, dtype: object

# %%
# Confirm that no Item or Price Per Unit values remain missing after imputation
remaining = data['Item'].isna().sum()
print(f'Remaining missing Item values: {remaining}')
data.to_csv("dataset_with_item_imputed.csv", index=False)
# Out:
# Remaining missing Item values: 0
